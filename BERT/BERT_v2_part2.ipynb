# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/jennifertang/Downloads/BERTv3_result.csv", index_col=0)

# %%
df.columns=['score']
df
# Out:
#           score
# 0      0.487045
# 1      0.138416
# 2      0.936081
# 3      0.908850
# 4      0.869992
# ...         ...
# 60211  0.928053
# 60212  0.928053
# 60213  0.993265
# 60214  0.993265
# 60215  0.993265
#
# [60216 rows x 1 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 60216 entries, 0 to 60215
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   score   60216 non-null  float64
# dtypes: float64(1)
# memory usage: 940.9 KB

# %%
less_toxic_score = []
for i in range(int(len(df)/2)):
    less_toxic_score.append(df.score[i])

# %%
len(less_toxic_score)
# Out:
# 30108

# %%
more_toxic_score = []
for i in range(int(len(df)/2)):
    more_toxic_score.append(df.score[i+30108])

# %%
len(more_toxic_score)
# Out:
# 30108

# %%
validation = pd.read_csv("/Users/jennifertang/Downloads/4. Jigsaw Rate Severity of Toxic Comments/dataset/validation_data.csv")

# %%
validation["less_toxic_score"] = less_toxic_score
validation["more_toxic_score"] = more_toxic_score

# %%
validation
# Out:
#        worker                                         less_toxic  \
# 0         313            This article sucks \n\nwoo woo wooooooo
# 1         188  "And yes, people should recognize that but the...
# 2          82   Western Media?\n\nYup, because every crime in...
# 3         347  And you removed it! You numbskull! I don't car...
# 4         539   smelly vagina \n\nBluerasberry why don't you ...
# ...       ...                                                ...
# 30103     461  I'm sorry. I'm not an admin. I will give you t...
# 30104     527  I'm sorry. I'm not an admin. I will give you t...
# 30105     352  wow...\nare you out of your mind, how was my e...
# 30106     311  wow...\nare you out of your mind, how was my e...
# 30107      54  wow...\nare you out of your mind, how was my e...
#
#                                               more_toxic  less_toxic_score  \
# 0      WHAT!!!!!!!!?!?!!?!?!!?!?!?!?!!!!!!!!!!!!!!!!!...          0.487045
# 1       Daphne Guinness \n\nTop of the mornin' my fav...          0.138416
# 2      "Atom you don't believe actual photos of mastu...          0.936081
# 3      You seem to have sand in your vagina.\n\nMight...          0.908850
# 4               hey \n\nway to support nazis, you racist          0.869992
# ...                                                  ...               ...
# 30103                             get out my large penis          0.157757
# 30104                             get out my large penis          0.157757
# 30105                       Piss off you slant eyed-gook          0.290036
# 30106                       Piss off you slant eyed-gook          0.290036
# 30107                       Piss off you slant eyed-gook          0.290036
#
#        more_toxic_score
# 0              0.678772
# 1              0.620155
# 2              0.181992
# 3              0.957018
# 4              0.985859
# ...                 ...
# 30103          0.928053
# 30104          0.928053
# 30105          0.993265
# 30106          0.993265
# 30107          0.993265
#
# [30108 rows x 5 columns]

# %%
def function(x):
    if x.less_toxic_score < x.more_toxic_score:
        return 1
    else:
        return 0
    
validation["comparison"] = validation[["less_toxic_score", "more_toxic_score"]].apply(function, axis=1)

# %%
validation
# Out:
#        worker                                         less_toxic  \
# 0         313            This article sucks \n\nwoo woo wooooooo
# 1         188  "And yes, people should recognize that but the...
# 2          82   Western Media?\n\nYup, because every crime in...
# 3         347  And you removed it! You numbskull! I don't car...
# 4         539   smelly vagina \n\nBluerasberry why don't you ...
# ...       ...                                                ...
# 30103     461  I'm sorry. I'm not an admin. I will give you t...
# 30104     527  I'm sorry. I'm not an admin. I will give you t...
# 30105     352  wow...\nare you out of your mind, how was my e...
# 30106     311  wow...\nare you out of your mind, how was my e...
# 30107      54  wow...\nare you out of your mind, how was my e...
#
#                                               more_toxic  less_toxic_score  \
# 0      WHAT!!!!!!!!?!?!!?!?!!?!?!?!?!!!!!!!!!!!!!!!!!...          0.487045
# 1       Daphne Guinness \n\nTop of the mornin' my fav...          0.138416
# 2      "Atom you don't believe actual photos of mastu...          0.936081
# 3      You seem to have sand in your vagina.\n\nMight...          0.908850
# 4               hey \n\nway to support nazis, you racist          0.869992
# ...                                                  ...               ...
# 30103                             get out my large penis          0.157757
# 30104                             get out my large penis          0.157757
# 30105                       Piss off you slant eyed-gook          0.290036
# 30106                       Piss off you slant eyed-gook          0.290036
# 30107                       Piss off you slant eyed-gook          0.290036
#
#        more_toxic_score  comparison
# 0              0.678772           1
# 1              0.620155           1
# 2              0.181992           0
# 3              0.957018           1
# 4              0.985859           1
# ...                 ...         ...
# 30103          0.928053           1
# 30104          0.928053           1
# 30105          0.993265           1
# 30106          0.993265           1
# 30107          0.993265           1
#
# [30108 rows x 6 columns]

# %%
validation.comparison.value_counts(normalize=1)
# Out:
# 1    0.646506
# 0    0.353494
# Name: comparison, dtype: float64
